# %% [markdown]
# # Titanic Basic Analysis
#
# This notebook provides a basic analysis of the Titanic dataset focusing on the following aspects:
#
# 1. **Age Distribution**: Visualization of age distribution among Titanic passengers.
# 2. **Gender Class Distribution**: Examination of gender-based distribution across passenger classes.
# 3. **Passenger Class Analysis**: Analysis of survival rates across different passenger classes.

# %% [markdown]
# ## Libraries Import
#
# Import necessary libraries for the analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style='whitegrid')

# %% [markdown]
# ## Data Loading
#
# Load the cleaned Titanic dataset. Handle errors in file loading to ensure smooth execution.

# %%
try:
    titanic_df = pd.read_csv('./datasets/preprocessed_dataset/stage_data.csv')
    print('Data loaded successfully.')
except FileNotFoundError:
    print('Error: File not found. Please check the file path.')
except Exception as e:
    print(f'An error occurred: {e}')
# Out:
# Data loaded successfully.

# %% [markdown]
# ## Age Distribution
#
# Visualize the distribution of passenger ages using histograms with overlaid KDE plots.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(titanic_df['age'].dropna(), kde=True, color='blue', bins=30)
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Gender Class Distribution
#
# Analyze gender distribution across passenger classes using a stacked bar chart.

# %%
plt.figure(figsize=(10, 6))
gender_class = pd.crosstab(titanic_df['pclass'], titanic_df['gender'])
gender_class.plot(kind='bar', stacked=True, color=['blue', 'red'], ax=plt.gca())
plt.title('Gender Distribution across Passenger Classes')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Passenger Class Analysis
#
# Analyze survival rates across passenger classes using a count plot for better visualization.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=titanic_df, x='pclass', hue='survived', order=[1, 2, 3])
plt.title('Survival by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
# Save the cleaned and explored dataset to a CSV file
titanic_df.to_csv('./datasets/results/cleaned_and_explored_titanic_data.csv', index=False)

print("Cleaned and explored dataset saved as 'cleaned_and_explored_titanic_data.csv'")
# Out:
# Cleaned and explored dataset saved as 'cleaned_and_explored_titanic_data.csv'
